# %%
import logRegres
from numpy import *

# %%
dataMat,labelMat = logRegres.loadDataSet()

# %%
len(dataMat)
# Out:
# 100

# %%
len(labelMat)
# Out:
# 100

# %%
wei = logRegres.gradAscent(dataMat,labelMat)

# %%
logRegres.plotBestFit(wei)

# %%
wei = logRegres.stocGradAscent0(array(dataMat),labelMat)
logRegres.plotBestFit(wei)

# %%
dataMat,labelMat = logRegres.loadDataSet()

# %%
wei = logRegres.stocGradAscent1(array(dataMat),labelMat)

# %%
wei
# Out:
# array([ 14.28659056,   1.18962081,  -1.77044813])

# %%
logRegres.plotBestFit(wei)

# %%
logRegres.multiTest()
# Out:
# C:\Users\Harsha SlimShady\Desktop\python\ML\MachineLearning_python\Logistic Regression\logRegres.py:19: RuntimeWarning: overflow encountered in exp
#   return 1.0/(1+exp(-inX))
# the error rate of this test is: 0.417910
# the error rate of this test is: 0.283582
# the error rate of this test is: 0.298507
# the error rate of this test is: 0.268657
# the error rate of this test is: 0.328358
# the error rate of this test is: 0.253731
# the error rate of this test is: 0.358209
# the error rate of this test is: 0.283582
# the error rate of this test is: 0.402985
# the error rate of this test is: 0.328358
# after 10 iterations the average error rate is: 0.322388
